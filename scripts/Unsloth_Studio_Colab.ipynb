# %% [markdown]
# <a href="https://colab.research.google.com/github/kayodekosi/Knat-LLM/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# fatal: destination path 'unsloth' already exists and is not an empty directory.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#   frontend       up to date
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/15  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [========------------]  6/15  dependency overrides   torch 2.11.0+cu128 detected -- installing torchao==0.17.0
#   deps           [====================] 15/15  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#                  existing install detected -- validating update
#   llama.cpp      prebuilt up to date and validated
#                  installed release: unslothai/llama.cpp@b10107-mix-1911198 (tag b10107)
#   whisper.cpp    no compatible prebuilt (installed llama.cpp b10107-mix-1911198; whisper requires b10079-mix-fb3d4ca); curated whisper.cpp dictation is unavailable; publish the paired releases in llama.cpp then whisper.cpp order; browser and Transformers dictation remain available
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# On Colab, start() auto-opens a Cloudflare link and prints admin login credentials.
# Use the Cloudflare link above the ready card to open Studio (in-cell iframes often stay blank).
start()

# To skip the Cloudflare tunnel and try the in-notebook proxy iframe only:
# start(cloudflare=False)
# Out:
# 2026-07-27 20:36:19 [info     ] 🦥 Starting Unsloth Studio...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# {"timestamp": "2026-07-27T20:36:50.043209Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-07-27T20:36:50.061607Z", "level": "info", "event": "   Starting server..."}
# {"timestamp": "2026-07-27T20:36:50.062438Z", "level": "info", "event": "run_server startup begin api_only=False host=0.0.0.0 port=8888"}
# {"timestamp": "2026-07-27T20:36:50.111542Z", "level": "info", "event": "Imported FastAPI app in 0.0ms"}
# {"timestamp": "2026-07-27T20:36:50.224688Z", "level": "info", "event": "Ensured Unsloth directories in 162.3ms"}
# {"timestamp": "2026-07-27T20:36:50.311723Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 249.3ms"}
# INFO:     Started server process [8176]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-07-27T20:36:50.473706Z", "level": "info", "event": "Removing unsloth compiled cache: /content/unsloth/unsloth_compiled_cache"}
# Hardware detected: CUDA -- Tesla T4
# {"timestamp": "2026-07-27T20:36:50.475449Z", "level": "info", "event": "lifespan hardware detection completed in 1.9ms"}
# {"timestamp": "2026-07-27T20:36:50.801456Z", "level": "info", "event": "lifespan pre-auth setup completed in 327.9ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-07-27T20:36:51.227210Z", "level": "info", "event": "lifespan startup completed in 753.7ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://35.252.242.242:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-07-27T20:36:51.336810Z", "level": "info", "event": "Uvicorn startup hook completed in 1274.4ms"}
# {"timestamp": "2026-07-27T20:36:51.338867Z", "level": "info", "event": "run_server uvicorn ready after 1276.5ms"}
# {"timestamp": "2026-07-27T20:36:51.358338Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-07-27T20:36:52.140960Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 776.99}
# {"timestamp": "2026-07-27T20:36:55.799526Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# {"timestamp": "2026-07-27T20:37:02.909113Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.37}
# {"timestamp": "2026-07-27T20:37:04.305093Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-usw1b2-6uk71ajp8n88-b.us-west1-2.prod.colab.dev"}
# {"timestamp": "2026-07-27T20:37:04.306113Z", "level": "info", "event": "\ud83d\udd17 Shareable Cloudflare link: https://neither-ruled-quiet-cent.trycloudflare.com"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Shareable Unsloth Link is Ready!
#         </h2>
#         <a href="https://neither-ruled-quiet-cent.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px; cursor: pointer;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             This Cloudflare HTTPS link works from any device, so you can share it with anyone.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             🔗 <a href="https://neither-ruled-quiet-cent.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#                   style="color: #000000; text-decoration: underline; cursor: pointer;">https://neither-ruled-quiet-cent.trycloudflare.com</a>
#         </p>
#         <p style="color: #000000; margin: 16px 0 0 0; font-size: 20px; font-weight: 800;">
#             Password
#         </p>
#         <p style="margin: 6px 0 0 0;"><code style="display: inline-block; font-size: 24px;
#             font-weight: 800; text-decoration: underline; background: #f3f3f3;
#             padding: 4px 10px; border-radius: 6px;">StadiumDifficultEatingNiece</code></p>
#         <p style="color: #666666; margin: 6px 0 0 0; font-size: 12px;">
#             Log in as <code>unsloth</code> with this password. Shown only in your
#             notebook session, and never included in the shared link.
#         </p>
#     </div>
# {"timestamp": "2026-07-27T20:38:13.658891Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 3.29}
# {"timestamp": "2026-07-27T20:38:14.054541Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 59.22}
# {"timestamp": "2026-07-27T20:38:29.469690Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.6}
# {"timestamp": "2026-07-27T20:38:30.213843Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.54}
# {"timestamp": "2026-07-27T20:38:35.831897Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 88.0}
# {"timestamp": "2026-07-27T20:38:36.980384Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 16.65}
# {"timestamp": "2026-07-27T20:38:36.988541Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-07-27T20:38:36.993097Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 9.03}
# {"timestamp": "2026-07-27T20:38:37.001817Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/personalization", "status_code": 200, "process_time_ms": 51.83}
# {"timestamp": "2026-07-27T20:38:37.048652Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 32.02}
# {"timestamp": "2026-07-27T20:38:37.053525Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 92.98}
# {"timestamp": "2026-07-27T20:38:37.207740Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.6-27B-MTP-GGUF', 'unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/Qwen-AgentWorld-35B-A3B-GGUF', 'unsloth/gemma-4-12b-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-MTP-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/gemma-4-26B-A4B-it-qat-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Kimi-K2.7-Code-GGUF', 'unsloth/GLM-5.2-GGUF', 'unsloth/Qwen3-8B-GGUF', 'unsloth/gemma-4-31B-it-qat-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/gemma-4-E4B-it-qat-GGUF', 'unsloth/bge-small-en-v1.5-GGUF', 'unsloth/gemma-4-12B-it-qat-GGUF', 'unsloth/Qwen3-VL-2B-Instruct-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3-235B-A22B-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/FLUX.2-klein-4B-GGUF', 'unsloth/inkling-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Laguna-S-2.1-GGUF', 'unsloth/DeepSeek-V4-Flash-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Ornith-1.0-35B-GGUF', 'unsloth/gemma-4-E2B-it-qat-GGUF']"}
# {"timestamp": "2026-07-27T20:38:37.209195Z", "level": "info", "event": "Top hub models: ['unsloth/Qwen3.6-27B-NVFP4', 'unsloth/Qwen3.6-35B-A3B-NVFP4', 'unsloth/Qwen3-VL-32B-Instruct-bnb-4bit', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-14B-Instruct', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/gemma-4-31B-it-unsloth-bnb-4bit', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Qwen3.6-35B-A3B-NVFP4-Fast', 'unsloth/Qwen3-Embedding-4B', 'unsloth/GLM-4.5-Air', 'unsloth/GLM-4.7-Flash', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-14B-bnb-4bit', 'unsloth/Qwen3-VL-2B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-4B', 'unsloth/bge-small-en-v1.5', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen3.5-2B', 'unsloth/llava-1.5-7b-hf-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/gemma-3-4b-it', 'unsloth/tinyllama-bnb-4bit', 'unsloth/Qwen3-8B', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/gemma-4-E4B-it', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/gemma-4-12b-it', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Qwen3-0.6B', 'unsloth/GLM-4.7-Flash-FP8-Dynamic']"}
# {"timestamp": "2026-07-27T20:38:37.236966Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/providers/", "status_code": 200, "process_time_ms": 20.56}
# {"timestamp": "2026-07-27T20:38:37.243664Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/providers/registry", "status_code": 200, "process_time_ms": 4.69}
# {"timestamp": "2026-07-27T20:38:38.221662Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-07-27T20:38:38.223449Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-07-27T20:38:38.225584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 7.09}
# {"timestamp": "2026-07-27T20:38:38.252702Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 24.12}
# {"timestamp": "2026-07-27T20:38:38.263148Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 9.36}
# {"timestamp": "2026-07-27T20:38:40.739704Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-07-27T20:38:42.309861Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 344.42}
# {"timestamp": "2026-07-27T20:38:42.732493Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 5.0}
# {"timestamp": "2026-07-27T20:38:42.941779Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 8.65}
# {"timestamp": "2026-07-27T20:38:43.845506Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 320.79}
# {"timestamp": "2026-07-27T20:38:46.008878Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-07-27T20:38:46.015315Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/upload-limit", "status_code": 200, "process_time_ms": 14.01}
# {"timestamp": "2026-07-27T20:38:50.258894Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 18.04}
# {"timestamp": "2026-07-27T20:39:06.328630Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.81}
# {"timestamp": "2026-07-27T20:39:08.328046Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 29.25}
# {"timestamp": "2026-07-27T20:39:50.225033Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 4.14}
# {"timestamp": "2026-07-27T20:39:52.268857Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.58}
# {"timestamp": "2026-07-27T20:40:19.727107Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.96}
# {"timestamp": "2026-07-27T20:40:20.707140Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 26.71}
# {"timestamp": "2026-07-27T20:40:41.878728Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/system/hardware", "status_code": 200, "process_time_ms": 37.79}
# {"timestamp": "2026-07-27T20:40:41.913046Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 16.93}
# {"timestamp": "2026-07-27T20:40:41.917726Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 3.13}
# {"timestamp": "2026-07-27T20:40:58.210353Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.8}
# {"timestamp": "2026-07-27T20:41:00.911544Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 2.51}
# {"timestamp": "2026-07-27T20:41:00.939943Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 16.17}
# ==={"timestamp": "2026-07-27T20:54:07.007787Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 5.06}
# {"timestamp": "2026-07-27T20:54:08.951217Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 19.63}
# {"timestamp": "2026-07-27T20:54:16.263028Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.78}
# {"timestamp": "2026-07-27T20:54:27.414649Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/helper-precache", "status_code": 200, "process_time_ms": 5.06}
# {"timestamp": "2026-07-27T20:54:27.430124Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.77}
# {"timestamp": "2026-07-27T20:54:27.432145Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/preview-sharing", "status_code": 200, "process_time_ms": 8.83}
# {"timestamp": "2026-07-27T20:54:27.711209Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 4.46}
# {"timestamp": "2026-07-27T20:54:47.678345Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/hugging-face-cache", "status_code": 200, "process_time_ms": 7.72}
# {"timestamp": "2026-07-27T20:54:59.567963Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/openai-auto-switch", "status_code": 200, "process_time_ms": 16.41}
# {"timestamp": "2026-07-27T20:54:59.577051Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/api-keys", "status_code": 200, "process_time_ms": 4.34}
# {"timestamp": "2026-07-27T20:54:59.591198Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/v1/models", "status_code": 200, "process_time_ms": 34.45}
# {"timestamp": "2026-07-27T20:54:59.811758Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.85}
# {"timestamp": "2026-07-27T20:54:59.836887Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.71}
# {"timestamp": "2026-07-27T20:55:01.212872Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/providers/registry", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-07-27T20:55:01.223584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/providers/", "status_code": 200, "process_time_ms": 3.25}
# {"timestamp": "2026-07-27T20:55:03.420527Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 25.66}
# {"timestamp": "2026-07-27T20:55:03.423476Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 41.77}
# {"timestamp": "2026-07-27T20:55:03.598025Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 171.74}
# {"timestamp": "2026-07-27T20:55:03.677561Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 6.81}
# {"timestamp": "2026-07-27T20:55:03.688579Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 9.59}
# {"timestamp": "2026-07-27T20:55:03.827371Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/providers/registry", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-07-27T20:55:11.005236Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 12.92}
# {"timestamp": "2026-07-27T20:55:11.223040Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/install-source", "status_code": 200, "process_time_ms": 235.3}
# ==={"timestamp": "2026-07-27T21:08:49.507071Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.7}
# {"timestamp": "2026-07-27T21:10:08.563151Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.98}
# {"timestamp": "2026-07-27T21:10:30.160048Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 17.81}
# {"timestamp": "2026-07-27T21:10:30.420601Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-07-27T21:10:49.505012Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.65}
# {"timestamp": "2026-07-27T21:10:52.498900Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 30.2}
# ={"timestamp": "2026-07-27T21:16:49.368898Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.52}
# {"timestamp": "2026-07-27T21:16:50.598466Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 18.19}
# {"timestamp": "2026-07-27T21:16:58.857964Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 2.19}
# {"timestamp": "2026-07-27T21:17:01.207622Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 25.13}
# {"timestamp": "2026-07-27T21:17:01.301011Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 4.57}
# {"timestamp": "2026-07-27T21:17:02.037750Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 724.38}
# {"timestamp": "2026-07-27T21:17:02.040134Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 730.18}
# {"timestamp": "2026-07-27T21:17:02.047988Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 743.71}
# {"timestamp": "2026-07-27T21:17:02.340893Z", "level": "info", "event": "Cached model scan: inspected=2 skipped_gguf=0 skipped_no_weights=0 skipped_stt=0 returned=0"}
# {"timestamp": "2026-07-27T21:17:02.344945Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 19.89}
# {"timestamp": "2026-07-27T21:17:02.469750Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 184.03}
# {"timestamp": "2026-07-27T21:17:02.503129Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 156.13}
# {"timestamp": "2026-07-27T21:17:02.507891Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 15.32}
# {"timestamp": "2026-07-27T21:17:02.557623Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 43.57}
# ={"timestamp": "2026-07-27T21:17:04.810029Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 8.25}
# {"timestamp": "2026-07-27T21:17:04.827962Z", "level": "info", "event": "Cached model scan: inspected=2 skipped_gguf=0 skipped_no_weights=0 skipped_stt=0 returned=0"}
# {"timestamp": "2026-07-27T21:17:04.830975Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 13.08}
# {"timestamp": "2026-07-27T21:17:04.848859Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 29.64}
# {"timestamp": "2026-07-27T21:17:39.779913Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 6.69}
# {"timestamp": "2026-07-27T21:17:50.784543Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 9.95}
# {"timestamp": "2026-07-27T21:17:50.791503Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 5.0}
# {"timestamp": "2026-07-27T21:17:51.349631Z", "level": "info", "event": "Cached model scan: inspected=2 skipped_gguf=0 skipped_no_weights=0 skipped_stt=0 returned=0"}
# {"timestamp": "2026-07-27T21:17:51.356524Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 40.42}
# {"timestamp": "2026-07-27T21:17:51.362723Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 45.0}
# {"timestamp": "2026-07-27T21:17:51.374700Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 51.18}
# {"timestamp": "2026-07-27T21:17:52.761304Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 2.96}
# {"timestamp": "2026-07-27T21:17:59.326110Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.93}
# {"timestamp": "2026-07-27T21:17:59.421769Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 18.02}
# {"timestamp": "2026-07-27T21:18:31.774782Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.99}
# {"timestamp": "2026-07-27T21:18:35.295151Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.86}
# {"timestamp": "2026-07-27T21:18:36.952326Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 28.48}
# {"timestamp": "2026-07-27T21:19:03.265279Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.27}
# {"timestamp": "2026-07-27T21:19:03.454350Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/install-source", "status_code": 200, "process_time_ms": 187.25}
# {"timestamp": "2026-07-27T21:19:07.646729Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 7.38}
# {"timestamp": "2026-07-27T21:19:07.648739Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/preview-sharing", "status_code": 200, "process_time_ms": 6.47}
# {"timestamp": "2026-07-27T21:20:09.478858Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.98}
# ={"timestamp": "2026-07-27T21:23:02.958268Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.59}
# {"timestamp": "2026-07-27T21:23:02.960407Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 9.42}
# {"timestamp": "2026-07-27T21:23:03.241281Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/preview-sharing", "status_code": 200, "process_time_ms": 4.29}
# {"timestamp": "2026-07-27T21:23:25.157321Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/shutdown", "status_code": 200, "process_time_ms": 4.14}
# {"timestamp": "2026-07-27T21:23:25.360374Z", "level": "info", "event": "Graceful shutdown initiated -- cleaning up subprocesses..."}
# {"timestamp": "2026-07-27T21:23:25.378266Z", "level": "info", "event": "All subprocesses cleaned up"}
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [8176]

# %%
# !ls -la /content/unsloth/studio/backend/colab.py   # should exist
# !ls /content/unsloth/studio/backend | head
# Out:
# -rw-r--r-- 1 root root 29550 Jul 27 20:19 /content/unsloth/studio/backend/colab.py
# assets
# auth
# cloudflare_tunnel.py
# colab.py
# core
# hub
# __init__.py
# loggers
# main.py
# mcp_server.py

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
